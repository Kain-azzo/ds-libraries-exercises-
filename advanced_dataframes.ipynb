# %%
# df.iloc[:1:4] #rows, #columns
# df.iloc[:1:4].agg(["max","min","mean"]).round(1)
# df.groupby("column_name").agg_function #NEED AGGREGATE FUNCTION
# df.groupby("room").max()
# df.groupby("room").agg(["min","max"])
# df.groupby("room").describe().T
# pd.concat([df1,df2, axis=0]) #0 is lengthwise 
# #use df.reset_index()
# pd.concat([df1,df2, axis=1]) #1 is widthwise
# #chnage names of columns to get rid of duplicates

# %%
# pd.merge(users,roles,how="inner",left_on="role_id,right_on="id",indicator=True)

# %%
# from env import host, username, password, database
# # import pandas as pd

# %%
# def get_db_url3(user,password,host,database):
#     return f'mysql+pymysql://{username}:{password}@{host}/{database}'

# %%
# fix = mpg["trans"].unique()
# fix = np.delete(fix,1)
# fix = np.delete(fix,1)

# %%
# when pulling more than one column, use double brackets!!!!![[]]
# Boolean masking df.head()
# df.room == "B"
# mask = df.room == "B"
# df[mask].name
# df.reset_index()# resets index
# df.math.agg("min","max","mean")
# df.math.max("max")
# df[["math,","reading","english"]].agg(["max","min","mean"]).round(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 # when pulling more than one column, use double brackets
#       2 # Boolean masking df.head()
# ----> 3 df.room == "B"
#       4 mask = df.room == "B"
#
# NameError: name 'df' is not defined

# %%
from env import host, username, password, database
import pandas as pd
def get_db_url():
    url =f'mysql+pymysql://{username}:{password}@{host}/{database}'
    return url

# %%
from env import host, username, password, database
import pandas as pd

# %%
url =f'mysql+pymysql://{username}:{password}@{host}/{database}'

query = 'SELECT * FROM employees LIMIT 5 OFFSET 50'

pd.read_sql(query,get_db_url())
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
pd.read_sql('select * from employees',get_db_url())
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
#Unknown columns error

query = 'SELECT ll FROM employees LIMIT 5 OFFSET 50'

pd.read_sql(query,get_db_url())

# %%
employees = pd.read_sql('select * from employees', url)

# %%
titles = pd.read_sql('select * from titles', url)

# %%
#url =f'mysql+pymysql://{username}:{password}@{host}/{database}'
def get_db_url2():
    url2 =f'mysql+pymysql://{username}:{password}@{host}/{database}'
    return url2
        
query2 = 'SELECT * FROM titles'

pd.read_sql(query2,get_db_url2())
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
yo = pd.DataFrame(pd.read_sql(query,get_db_url()))
yo
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %%
titles.describe(include="all")
# Out:
#                emp_no     title   from_date     to_date
# count   443308.000000    443308      443308      443308
# unique            NaN         7        6393        5888
# top               NaN  Engineer  1998-10-25  9999-01-01
# freq              NaN    115003         132      240124
# mean    253075.034430       NaN         NaN         NaN
# std     161853.292613       NaN         NaN         NaN
# min      10001.000000       NaN         NaN         NaN
# 25%      84855.750000       NaN         NaN         NaN
# 50%     249847.500000       NaN         NaN         NaN
# 75%     424891.250000       NaN         NaN         NaN
# max     499999.000000       NaN         NaN         NaN

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
titles.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %%
titles.title.unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %%
titles.title.unique().shape
# Out:
# (7,)

# %%
len(titles.title.unique())
# Out:
# 7

# %%
titles.title.nunique()
# Out:
# 7

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
import numpy as np
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
users.merge(roles,how="right",left_on="role_id",right_on="id",indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
users.merge(roles,how="left",left_on="role_id",right_on="id",indicator=True)
# Out:
#    id_x name_x  role_id  id_y    name_y     _merge
# 0     1    bob      1.0   1.0     admin       both
# 1     2    joe      2.0   2.0    author       both
# 2     3  sally      3.0   3.0  reviewer       both
# 3     4   adam      3.0   3.0  reviewer       both
# 4     5   jane      NaN   NaN       NaN  left_only
# 5     6   mike      NaN   NaN       NaN  left_only

# %%
users.merge(roles,how="inner",left_on="role_id",right_on="id",indicator=True)
# Out:
#    id_x name_x  role_id  id_y    name_y _merge
# 0     1    bob      1.0     1     admin   both
# 1     2    joe      2.0     2    author   both
# 2     3  sally      3.0     3  reviewer   both
# 3     4   adam      3.0     3  reviewer   both

# %%
users.merge(roles,how="outer",left_on="role_id",right_on="id",indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
messup= users.drop(columns="role_id")
#What happens if you drop the foreign keys from the DataFrames and try to merge them?
#Wont allow you to correctly connect and reference different tables

# %%
from pydataset import data
mpg = data('mpg') # load the dataset and store it in a variable

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.shape #234 rows 11 columns
# Out:
# (234, 11)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
len(mpg.manufacturer.unique()) #15
# Out:
# 15

# %%
len(mpg.model.unique()) #38
# Out:
# 38

# %%
#shift+tab on mpg to read docs
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg["mileage_difference"] = mpg["hwy"] - mpg["cty"]

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
mpg["average_mileage"] = (mpg["hwy"] + mpg["cty"])/2

# %%
# fix
# Out:
# array(['auto(l5)', 'auto(av)', 'auto(s6)', 'auto(l4)', 'auto(l3)',
#        'auto(l6)', 'auto(s5)', 'auto(s4)'], dtype=object)

# %%
#automatic = (fix == "auto(l5)") | (fix == "auto(lav)") |(fix == "auto(l4)") | (fix == "auto(l3)") | (fix == "auto(l6)") | (fix == "auto(s5)") | (fix == "auto(s4)")

# %%
mpg["is_automatic"] = np.where(mpg.trans.str.startswith("auto"),True,False)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     car_class  is_automatic  average_mileage
# 1     compact          True             23.5
# ...

# %%
#volkswagon max mileage
mpg[["average_mileage","manufacturer"]].groupby("manufacturer").agg("max")
# Out:
#               average_mileage
# manufacturer
# audi                     25.5
# chevrolet                26.0
# dodge                    21.0
# ford                     22.0
# honda                    30.5
# hyundai                  26.0
# jeep                     19.5
# land rover               15.0
# lincoln                  15.0
# mercury                  16.0
# nissan                   27.5
# pontiac                  23.0
# subaru                   23.5
# toyota                   32.5
# volkswagen               39.5

# %%
#automatic best mileage for each car, same result -- FIX!!!
mpg.groupby('is_automatic').agg("mean")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# ...

# %%
from env import host, username, password, database2
def get_db_url3():
    url3 =f'mysql+pymysql://{username}:{password}@{host}/{database2}'
    return url3
        
query3 = 'SELECT * FROM orders'

pd.read_sql(query3,get_db_url3())
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
chipotle.head(4)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                nan     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39
# 3                nan     $2.39

# %%
chipotle["item_price"] = chipotle["item_price"].str.strip("$")

# %%
chipotle["item_price"] = chipotle["item_price"].astype(float)

# %%
# chipotle = pd.read_sql(query3,get_db_url3())

# # pd.crosstab(chipotle.order_id,chipotle.item_price,margins=True)
chipotle.groupby(chipotle.order_id).agg("sum")
# Out:
#              id  quantity  \
# order_id
# 1            10         4
# 2             5         2
# 3            13         2
# 4            17         2
# 5            21         2
# ...         ...       ...
# 1830       9223         2
# 1831      13842         3
# 1832       9233         2
# 1833       9237         2
# 1834      13863         3
#
#                                                                                       item_name  \
# order_id
# 1         Chips and Fresh Tomato SalsaIzzeNantucket NectarChips and Tomatillo-Green Chili Salsa
# 2                                                                                  Chicken Bowl
# 3                                                                     Chicken BowlSide of Chips
# 4                                                                 Steak BurritoSteak Soft Tacos
# 5                                                              Steak BurritoChips and Guacamole
# ...

# %%
chipotle.groupby("item_name").agg("sum").sort_values(by="quantity",ascending=False)
#chicken bowl, chicken burrrito, chips and gaucamole
#chicken bowl also produced the most revenue
# Out:
#                                             id  order_id  quantity  \
# item_name
# Chicken Bowl                           1780635    713926       761
# Chicken Burrito                        1238770    497303       591
# Chips and Guacamole                    1122252    449959       506
# Steak Burrito                           818163    328437       386
# Canned Soft Drink                       760291    304753       351
# Chips                                   518915    208004       230
# Steak Bowl                              482932    193752       221
# Bottled Water                           439516    175944       211
# Chips and Fresh Tomato Salsa            250254    100419       130
# Canned Soda                             190019     76396       126
# Chicken Salad Bowl                      292402    117104       123
# Chicken Soft Tacos                      245006     98395       120
# Side of Chips                           211110     84769       110
# ...

# %%
query5 = '''SELECT * FROM employees 
                        join titles
                            using(emp_no)
                            '''
joined= pd.read_sql(query5,get_db_url())
joined
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %%
joined.groupby("title").hire_date.agg("max")
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
pd.read_sql("show tables",url)
# Out:
#   Tables_in_employees
# 0         departments
# 1            dept_emp
# 2        dept_manager
# 3           employees
# 4            salaries
# 5              titles

# %%
query6 = '''SELECT * FROM dept_emp
                        join departments
                            using(dept_no)
                            '''

# %%
df_depts = pd.read_sql(query6, url)

# %%
titles = pd.read_sql('select * from titles', url)

# %%
employees = pd.read_sql('select * from employees', url)

# %%
df_emps = pd.merge(employees,titles,how= "inner",on="emp_no")

# %%
join_all=pd.merge(df_emps, df_depts,how="inner",on="emp_no")
join_all.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title from_date_x   to_date_x dept_no from_date_y   to_date_y  \
# 0  Senior Engineer  1986-06-26  9999-01-01    d005  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01    d007  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01    d004  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01    d004  1986-12-01  9999-01-01
# 4  Senior Engineer  1995-12-01  9999-01-01    d004  1986-12-01  9999-01-01
#
#      dept_name
# 0  Development
# 1        Sales
# 2   Production
# 3   Production
# 4   Production

# %%
pd.crosstab(join_all.title,join_all.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   manufacturer     234 non-null    object
#  1   model            234 non-null    object
#  2   displ            234 non-null    float64
#  3   year             234 non-null    int64
#  4   cyl              234 non-null    int64
#  5   trans            234 non-null    object
#  6   drv              234 non-null    object
#  7   cty              234 non-null    int64
#  8   hwy              234 non-null    int64
#  9   fl               234 non-null    object
#  10  class            234 non-null    object
#  11  is_automatic     234 non-null    bool
#  12  average_mileage  234 non-null    float64
# dtypes: bool(1), float64(2), int64(4), object(6)
# memory usage: 24.0+ KB

# %%
mpg = mpg.rename(columns={'class':'car_class'})

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     car_class  is_automatic  average_mileage
# 1     compact          True             23.5
# ...
